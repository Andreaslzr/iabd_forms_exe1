# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
import seaborn as sns

# %%
velocidade = np.array([10,5,8,6,12,4])
complexidade = np.array(['baixa','alta','media','alta','baixa','alta'])
manutencao = np.array(['baixa','alta','media','alta','baixa','media'])
classificacao = np.array(['montagem','teste','montagem','teste','montagem','teste'])

# %%
velocidade_treino, velocidade_teste, classificacao_treino, classificacao_teste = train_test_split(velocidade.reshape(-1,1),classificacao.reshape(-1,1),test_size=0.2,random_state=42)

# %%
modelo = DecisionTreeClassifier()
modelo.fit(velocidade_treino,classificacao_treino)
# Out:
# DecisionTreeClassifier()

# %%
fig = plt.figure(figsize=(10,8))
tree.plot_tree(modelo,feature_names=velocidade.tolist(), class_names=classificacao.tolist(), filled=True)
# Out:
# [Text(0.5, 0.75, '10 <= 7.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = montagem'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = teste'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = montagem')]

# %%
sns.boxplot(x=classificacao, y=velocidade)
plt.title('classificação com base na velocidade de operação')
plt.ylabel('velocidade')
plt.xlabel('classificação')
# Out:
# Text(0.5, 0, 'classificação')

# %%
sns.barplot(y=velocidade, x=classificacao)
sns.set(font_scale=1)
plt.title('classificação com base na velocidade de operação',fontsize=20)
plt.xlabel('classificação', fontsize=16)
plt.ylabel('velocidade',fontsize=16)
# Out:
# Text(0, 0.5, 'velocidade')

# %%
y_pred=modelo.predict(velocidade_teste)
y_pred
# Out:
# array(['montagem', 'teste'], dtype='<U8')

# %%
modelo.predict(np.array([8]).reshape(-1,1))
# Out:
# array(['montagem'], dtype='<U8')

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
acuracia = accuracy_score(y_pred, classificacao_teste)
acuracia
# Out:
# 1.0

# %%
matrix = confusion_matrix(y_pred, classificacao_teste)
matrix
# Out:
# array([[1, 0],
#        [0, 1]], dtype=int64)
